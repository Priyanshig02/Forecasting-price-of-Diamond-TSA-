# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\dell\Downloads\df_diamond_data_merged_with_other_variables.csv", engine='python')
df
# Out:
#       Unnamed: 0        date  diamond price  inflation rate  interest rate  \
# 0              0  2021-06-04       10385.16            2.40          -0.84
# 1              1  2021-06-03       10385.16            2.42          -0.79
# 2              2  2021-06-02       10378.43            2.44          -0.85
# 3              3  2021-06-01       10376.10            2.46          -0.84
# 4              4  2021-05-31       10368.67             NaN            NaN
# ...          ...         ...            ...             ...            ...
# 1129        1129  2018-05-02       10047.16            2.17           0.80
# 1130        1130  2018-05-01       10050.07            2.16           0.81
# 1131        1131  2018-04-30       10038.62            2.17           0.78
# 1132        1132  2018-04-29       10032.95             NaN            NaN
# 1133        1133  2018-04-28       10030.58             NaN            NaN
#
#       fed rate  gold price
# 0         0.06     1890.97
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'diamond price', 'inflation rate',
#        'interest rate', 'fed rate', 'gold price'],
#       dtype='object')

# %%
df.set_index('date', inplace=True)
df
# Out:
#             Unnamed: 0  diamond price  inflation rate  interest rate  \
# date
# 2021-06-04           0       10385.16            2.40          -0.84
# 2021-06-03           1       10385.16            2.42          -0.79
# 2021-06-02           2       10378.43            2.44          -0.85
# 2021-06-01           3       10376.10            2.46          -0.84
# 2021-05-31           4       10368.67             NaN            NaN
# ...                ...            ...             ...            ...
# 2018-05-02        1129       10047.16            2.17           0.80
# 2018-05-01        1130       10050.07            2.16           0.81
# 2018-04-30        1131       10038.62            2.17           0.78
# 2018-04-29        1132       10032.95             NaN            NaN
# 2018-04-28        1133       10030.58             NaN            NaN
#
#             fed rate  gold price
# date
# 2021-06-04      0.06     1890.97
# 2021-06-03      0.06     1871.36
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'diamond price', 'inflation rate', 'interest rate',
#        'fed rate', 'gold price'],
#       dtype='object')

# %%
df=df.drop(['Unnamed: 0', 'inflation rate', 'interest rate',
       'fed rate', 'gold price'],axis=1)

# %%
df
# Out:
#             diamond price
# date
# 2021-06-04       10385.16
# 2021-06-03       10385.16
# 2021-06-02       10378.43
# 2021-06-01       10376.10
# 2021-05-31       10368.67
# ...                   ...
# 2018-05-02       10047.16
# 2018-05-01       10050.07
# 2018-04-30       10038.62
# 2018-04-29       10032.95
# 2018-04-28       10030.58
#
# [1134 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1134 entries, 2021-06-04 to 2018-04-28
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   diamond price  1134 non-null   float64
# dtypes: float64(1)
# memory usage: 17.7+ KB

# %%
df.describe().T
# Out:
#                 count          mean         std      min        25%       50%  \
# diamond price  1134.0  10015.655705  413.201619  9272.28  9766.0075  10005.11
#
#                      75%        max
# diamond price  10305.285  10804.857

# %%
import pandas as pd

# Assuming df is your DataFrame with time series data
# Reverse the order of rows
df = df[::-1].reset_index()

# Print the reversed DataFrame
print(df)
# Out:
#             date  diamond price
# 0     2018-04-28       10030.58
# 1     2018-04-29       10032.95
# 2     2018-04-30       10038.62
# 3     2018-05-01       10050.07
# 4     2018-05-02       10047.16
# ...          ...            ...
# 1129  2021-05-31       10368.67
# 1130  2021-06-01       10376.10
# 1131  2021-06-02       10378.43
# 1132  2021-06-03       10385.16
# 1133  2021-06-04       10385.16
#
# [1134 rows x 2 columns]

# %%
df
# Out:
#             date  diamond price
# 0     2018-04-28       10030.58
# 1     2018-04-29       10032.95
# 2     2018-04-30       10038.62
# 3     2018-05-01       10050.07
# 4     2018-05-02       10047.16
# ...          ...            ...
# 1129  2021-05-31       10368.67
# 1130  2021-06-01       10376.10
# 1131  2021-06-02       10378.43
# 1132  2021-06-03       10385.16
# 1133  2021-06-04       10385.16
#
# [1134 rows x 2 columns]

# %%
df.set_index('date', inplace=True)
df
# Out:
#             diamond price
# date
# 2018-04-28       10030.58
# 2018-04-29       10032.95
# 2018-04-30       10038.62
# 2018-05-01       10050.07
# 2018-05-02       10047.16
# ...                   ...
# 2021-05-31       10368.67
# 2021-06-01       10376.10
# 2021-06-02       10378.43
# 2021-06-03       10385.16
# 2021-06-04       10385.16
#
# [1134 rows x 1 columns]

# %%
# Plot the 'Close' prices over time
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['diamond price'], label='Diamond Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Diamond Prices Over Time')
plt.legend()
plt.show()

# %%
# Summary statistics
print(df.describe())

# Histogram of 'Diamond' prices
plt.figure(figsize=(12, 6))
plt.hist(df['diamond price'], bins=20, edgecolor='black')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Diamond Prices')
plt.show()
# Out:
#        diamond price
# count    1134.000000
# mean    10015.655705
# std       413.201619
# min      9272.280000
# 25%      9766.007500
# 50%     10005.110000
# 75%     10305.285000
# max     10804.857000

# %%
import matplotlib.pyplot as plt

# Customizing the style
plt.style.use('seaborn-darkgrid')

# Create a boxplot for diamond price with customized colors and styles
plt.figure(figsize=(12, 6))
plt.boxplot(df['diamond price'], patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'), 
            whiskerprops=dict(color='black'), capprops=dict(color='black'), medianprops=dict(color='orange'))
plt.title('Distribution of Diamond Prices', fontsize=16, fontweight='bold')
plt.ylabel('Price', fontsize=14)
plt.xticks([1], ['Diamond Prices'], fontsize=14)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding a decorative background color
plt.gca().set_facecolor('lightgray')

plt.show()

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
import pandas as pd

# Convert index to datetime if it's not already in datetime format
df.index = pd.to_datetime(df.index)

# Seasonal decomposition
decomposition = seasonal_decompose(df['diamond price'], period=50)  # Adjust period as per your data's seasonality
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot the decomposition components with enhancements
plt.figure(figsize=(14, 10))  # Increased figure size for better visibility
plt.subplot(411)
plt.plot(df.index, df['diamond price'], color='blue', label='Original')  # Added color for Original
plt.legend(loc='upper left')
plt.title('Seasonal Decomposition of Diamond Price')  # Added title
plt.subplot(412)
plt.plot(df.index, trend, color='green', label='Trend')  # Added color for Trend
plt.legend(loc='upper left')
plt.subplot(413)
plt.plot(df.index, seasonal, color='red', label='Seasonality')  # Added color for Seasonality
plt.legend(loc='upper left')
plt.subplot(414)
plt.plot(df.index, residual, color='purple', label='Residuals')  # Added color for Residuals
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np

# Convert datetime index to numerical values
x_values = mdates.date2num(df.index)

# Calculate residuals
residuals = df['diamond price'] - trend - seasonal

# Square the residuals
squared_residuals = residuals ** 2

# Plot squared residuals against time with trend line
plt.figure(figsize=(12, 6))
plt.plot(x_values, squared_residuals, marker='o', linestyle='-', color='blue', label='Squared Residuals')
plt.plot(x_values, np.ones_like(x_values) * squared_residuals.mean(), linestyle='--', color='red', label='Mean Squared Residuals')
plt.xlabel('Date')
plt.ylabel('Squared Residuals')
plt.title('Squared Residuals vs. Time with Trend Line')
plt.legend()
plt.grid(True)  # Add grid lines for better readability
plt.show()

# Plot squared residuals against fitted values
plt.figure(figsize=(12, 6))
plt.scatter(df['diamond price'], squared_residuals, color='green', alpha=0.6, label='Squared Residuals')
plt.plot(np.unique(df['diamond price']), np.poly1d(np.polyfit(df['diamond price'], squared_residuals, 1))(np.unique(df['diamond price'])), color='blue', linestyle='--', label='Trend Line')
plt.xlabel('Fitted Values')
plt.ylabel('Squared Residuals')
plt.title('Squared Residuals vs. Fitted Values with Trend Line')
plt.legend()
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %%
import numpy as np
from statsmodels.stats.diagnostic import het_breuschpagan

# Add a constant column to the exogenous variables
exog = np.column_stack((np.ones(len(residuals)), df[['diamond price']]))

# Perform Breusch-Pagan test for heteroskedasticity
bp_test = het_breuschpagan(residuals, exog)

# Extract test statistics and p-values
test_statistic = bp_test[0]
p_value = bp_test[1]

print('Breusch-Pagan Test Results:')
print('Test Statistic:', test_statistic)
print('p-value:', p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print('Reject the null hypothesis: Evidence of heteroskedasticity')
else:
    print('Fail to reject the null hypothesis: No evidence of heteroskedasticity')
# Out:
# Breusch-Pagan Test Results:
# Test Statistic: nan
# p-value: nan
# Fail to reject the null hypothesis: No evidence of heteroskedasticity

# %%
from statsmodels.tsa.stattools import adfuller

# Perform Augmented Dickey-Fuller test for stationarity
adf_test = adfuller(df['diamond price'])

# Extract test statistics and p-values
test_statistic = adf_test[0]
p_value = adf_test[1]
critical_values = adf_test[4]

print('Augmented Dickey-Fuller Test Results:')
print('Test Statistic:', test_statistic)
print('p-value:', p_value)
print('Critical Values:')
for key, value in critical_values.items():
    print(key, ':', value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print('Reject the null hypothesis: The data is stationary')
else:
    print('Fail to reject the null hypothesis: The data is non-stationary')
# Out:
# Augmented Dickey-Fuller Test Results:
# Test Statistic: -0.4823582538720232
# p-value: 0.8954134305323495
# Critical Values:
# 1% : -3.436139921033549
# 5% : -2.86409660029079
# 10% : -2.568131202693254
# Fail to reject the null hypothesis: The data is non-stationary

# %%
# Perform differencing until the data becomes stationary
def difference_data(data, n_diff=1):
    """
    Function to difference the data by a specified number of lags.

    Parameters:
    - data: pandas Series or DataFrame containing the time series data.
    - n_diff: int, the number of differences to perform (default is 1).

    Returns:
    - differenced_data: pandas Series or DataFrame, the differenced data.
    """
    differenced_data = data.diff(n_diff)
    return differenced_data.dropna()

# Example usage: Differencing the 'Close' prices once
df_diff = difference_data(df['diamond price'], n_diff=1)

# Display the differenced data
print(df_diff)
# Out:
# date
# 2018-04-29     2.37
# 2018-04-30     5.67
# 2018-05-01    11.45
# 2018-05-02    -2.91
# 2018-05-03    -1.14
#               ...
# 2021-05-31     2.98
# 2021-06-01     7.43
# 2021-06-02     2.33
# 2021-06-03     6.73
# 2021-06-04     0.00
# Name: diamond price, Length: 1133, dtype: float64

# %%
from statsmodels.tsa.stattools import adfuller

# Perform Augmented Dickey-Fuller test for stationarity on differenced data
adf_test_diff = adfuller(df_diff)

# Extract test statistics and p-values
test_statistic_diff = adf_test_diff[0]
p_value_diff = adf_test_diff[1]
critical_values_diff = adf_test_diff[4]

print('Augmented Dickey-Fuller Test Results (After Differencing):')
print('Test Statistic:', test_statistic_diff)
print('p-value:', p_value_diff)
print('Critical Values:')
for key, value in critical_values_diff.items():
    print(key, ':', value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value_diff < alpha:
    print('Reject the null hypothesis: The differenced data is stationary')
else:
    print('Fail to reject the null hypothesis: The differenced data is non-stationary')
# Out:
# Augmented Dickey-Fuller Test Results (After Differencing):
# Test Statistic: -30.065594891941853
# p-value: 0.0
# Critical Values:
# 1% : -3.436139921033549
# 5% : -2.86409660029079
# 10% : -2.568131202693254
# Reject the null hypothesis: The differenced data is stationary

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Define figure size
fig, axes = plt.subplots(2, 1, figsize=(12, 10))

# Plot ACF of differenced data
plot_acf(df_diff, lags=20, ax=axes[0])  # Adjust the number of lags as needed
axes[0].set_xlabel('Lag')
axes[0].set_ylabel('Autocorrelation')
axes[0].set_title('Autocorrelation Function (ACF) of Differenced Data')
axes[0].grid(True)  # Add grid lines for better readability

# Plot PACF of differenced data
plot_pacf(df_diff, lags=20, ax=axes[1])  # Adjust the number of lags as needed
axes[1].set_xlabel('Lag')
axes[1].set_ylabel('Partial Autocorrelation')
axes[1].set_title('Partial Autocorrelation Function (PACF) of Differenced Data')
axes[1].grid(True)  # Add grid lines for better readability

# Adjust layout
plt.tight_layout()

# Show plots
plt.show()
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import numpy as np

# Define figure and axes
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Plot ACF of differenced data
plot_acf(df_diff, lags=20, ax=ax1, title='Autocorrelation Function (ACF)', marker='o', color='b', alpha=0.5)
ax1.axhline(y=1.96/np.sqrt(len(df_diff)), linestyle='--', color='gray')  # Add upper significance level
ax1.axhline(y=-1.96/np.sqrt(len(df_diff)), linestyle='--', color='gray')  # Add lower significance level
ax1.set_xlabel('Lag')
ax1.set_ylabel('ACF')
ax1.grid(True)

# Plot PACF of differenced data
plot_pacf(df_diff, lags=20, ax=ax2, title='Partial Autocorrelation Function (PACF)', marker='o', color='r', alpha=0.5)
ax2.axhline(y=1.96/np.sqrt(len(df_diff)), linestyle='--', color='gray')  # Add upper significance level
ax2.axhline(y=-1.96/np.sqrt(len(df_diff)), linestyle='--', color='gray')  # Add lower significance level
ax2.set_xlabel('Lag')
ax2.set_ylabel('PACF')
ax2.grid(True)

# Adjust layout
plt.tight_layout()

# Show plots
plt.show()

# %%
# Perform seasonal differencing
seasonal_difference = df['diamond price'] - df['diamond price'].shift(2)  # Assuming a yearly seasonality (12 months)

# Plot the seasonally differenced data
plt.figure(figsize=(10, 6))
plt.plot(seasonal_difference, color='purple', label='Seasonally Differenced Data')
plt.xlabel('Date')
plt.ylabel('Seasonally Differenced Price')
plt.title('Seasonally Differenced Diamond Prices')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
#Assuming seasonal difference has been performed and stored in seasonal_difference_series
seasonal_difference_series = df['diamond price'] - df['diamond price'].shift(2)

# Perform trend analysis using moving averages
window_size = 12  # Window size for moving average (assuming yearly seasonality)
moving_avg = seasonal_difference_series.rolling(window=window_size).mean()

# Plot the original data and the trend component
plt.figure(figsize=(10, 6))
plt.plot(seasonal_difference_series, color='blue', label='Seasonality-Adjusted Data')
plt.plot(moving_avg, color='red', linestyle='--', label='Moving Average (Trend)')
plt.xlabel('Date')
plt.ylabel('Seasonally Adjusted Price')
plt.title('Trend Analysis of Seasonally Adjusted Diamond Prices')
plt.legend()
plt.show()

# %%
# Assuming seasonal_difference_series is your seasonality-adjusted time series data
# You need to replace seasonal_difference_series with your actual data
# You also need to ensure that your data is in pandas DataFrame or Series format

# Define the percentage split for training and testing data
train_ratio = 0.8  # 80% of data for training, 20% for testing

# Calculate the index to split the data
split_index = int(len(seasonal_difference_series) * train_ratio)

# Split the data into training and testing sets
train_data = seasonal_difference_series[:split_index]
test_data = seasonal_difference_series[split_index:]

# Optionally, you can also split the data into features (X) and target (y) if you're using machine learning models
# For TSA, you typically don't need to do this as you're working directly with time series data

# Print the lengths of the training and testing sets to verify the split
print("Training data length:", len(train_data))
print("Testing data length:", len(test_data))
# Out:
# Training data length: 907
# Testing data length: 227
